# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                 address                                    categories  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#            city country   latitude  longitude            name postalCode  \
# ...

# %%
FastFood_profile_df = FastFood_profile_df.loc[FastFood_profile_df['city']=='Chicago']
FastFood_profile_df.head()
# Out:
#                         id             dateAdded           dateUpdated  \
# 305   AVwclXRy_7pvs4fzwt99  2015-09-28T10:10:40Z  2018-06-24T02:21:55Z
# 563   AVwcmw-a_7pvs4fzw-HT  2016-03-24T09:34:47Z  2018-06-22T18:32:00Z
# 1624  AVwdY4j2ByjofQCxomRW  2017-03-09T18:02:53Z  2018-06-21T11:42:02Z
# 2204  AVwejLL7IN2L1WUf5_Jf  2017-03-09T18:02:50Z  2018-06-17T23:15:25Z
# 2205  AV1TsHBZ3D1zeR_xFFGA  2017-07-18T03:14:18Z  2018-06-17T23:15:24Z
#
#                     address  \
# 305   5636 W Irving Park Rd
# 563    7536 N Milwaukee Ave
# 1624        2810 N Clark St
# 2204           16 W Ohio St
# 2205      5853 S Kedzie Ave
#
#                                              categories     city country  \
# 305                                           Fast Food  Chicago      US
# 563   Fried Chicken Joint, Fast Food Restaurant, and...  Chicago      US
# 1624                               Fast Food Restaurant  Chicago      US
# ...

# %%
FastFood_profile_df = FastFood_profile_df.drop_duplicates('id')
FastFood_profile_df.head()
# Out:
#                         id             dateAdded           dateUpdated  \
# 305   AVwclXRy_7pvs4fzwt99  2015-09-28T10:10:40Z  2018-06-24T02:21:55Z
# 563   AVwcmw-a_7pvs4fzw-HT  2016-03-24T09:34:47Z  2018-06-22T18:32:00Z
# 1624  AVwdY4j2ByjofQCxomRW  2017-03-09T18:02:53Z  2018-06-21T11:42:02Z
# 2204  AVwejLL7IN2L1WUf5_Jf  2017-03-09T18:02:50Z  2018-06-17T23:15:25Z
# 2205  AV1TsHBZ3D1zeR_xFFGA  2017-07-18T03:14:18Z  2018-06-17T23:15:24Z
#
#                     address  \
# 305   5636 W Irving Park Rd
# 563    7536 N Milwaukee Ave
# 1624        2810 N Clark St
# 2204           16 W Ohio St
# 2205      5853 S Kedzie Ave
#
#                                              categories     city country  \
# 305                                           Fast Food  Chicago      US
# 563   Fried Chicken Joint, Fast Food Restaurant, and...  Chicago      US
# 1624                               Fast Food Restaurant  Chicago      US
# ...

# %%
# Transformation
FastFood_profile_df_transformed = FastFood_profile_df[['name', 'postalCode','province']]
FastFood_profile_df_transformed.head()
# Out:
#               name postalCode province
# 305    Dairy Queen      60634       IL
# 563    Chicken Inn      60631       IL
# 1624  Jimmy John's      60657       IL
# 2204        Subway      60610       IL
# 2205        Subway      60629       IL

# %%
FastFood_profile_df = FastFood_profile_df.drop_duplicates('id')
FastFood_profile_df.head()
# Out:
#                         id             dateAdded           dateUpdated  \
# 305   AVwclXRy_7pvs4fzwt99  2015-09-28T10:10:40Z  2018-06-24T02:21:55Z
# 563   AVwcmw-a_7pvs4fzw-HT  2016-03-24T09:34:47Z  2018-06-22T18:32:00Z
# 1624  AVwdY4j2ByjofQCxomRW  2017-03-09T18:02:53Z  2018-06-21T11:42:02Z
# 2204  AVwejLL7IN2L1WUf5_Jf  2017-03-09T18:02:50Z  2018-06-17T23:15:25Z
# 2205  AV1TsHBZ3D1zeR_xFFGA  2017-07-18T03:14:18Z  2018-06-17T23:15:24Z
#
#                     address  \
# 305   5636 W Irving Park Rd
# 563    7536 N Milwaukee Ave
# 1624        2810 N Clark St
# 2204           16 W Ohio St
# 2205      5853 S Kedzie Ave
#
#                                              categories     city country  \
# 305                                           Fast Food  Chicago      US
# 563   Fried Chicken Joint, Fast Food Restaurant, and...  Chicago      US
# 1624                               Fast Food Restaurant  Chicago      US
# ...

# %%
FastFood_profile_df_renamed = FastFood_profile_df_transformed.rename({'name':'NAME', 'postalCode':'ZIPCode', 'province':'PROVINCE'}, axis='columns')
FastFood_profile_df_renamed.head()
# Out:
#               NAME ZIPCode PROVINCE
# 305    Dairy Queen   60634       IL
# 563    Chicken Inn   60631       IL
# 1624  Jimmy John's   60657       IL
# 2204        Subway   60610       IL
# 2205        Subway   60629       IL

# %%
# extract Death by Zipcode
DeathByZip_file = "deaths-by-zip-code-by-cause-of-death-1999-current.csv"
DeathByZip_df = pd.io.parsers.read_csv(DeathByZip_file,encoding = 'unicode_escape',dtype={'ZIP Code': 'str'})
DeathByZip_df.head()
# Out:
#    Year ZIP Code Causes of Death Code  \
# 0  1999    90001                  ALZ
# 1  1999    90001                  CAN
# 2  1999    90001                  CLD
# 3  1999    90001                  DIA
# 4  1999    90001                  HOM
#
#                             Causes of Death  Count
# 0                       Alzheimer's Disease      3
# 1             Malignant Neoplasms (Cancers)     53
# 2  Chronic Lower Respiratory Disease (CLRD)     16
# 3                         Diabetes Mellitus     16
# 4                                  Homicide     11

# %%
DeathByZip_df_transformed = DeathByZip_df[['Year', 'ZIP Code','Causes of Death','Count']]
DeathByZip_df_transformed.head()
# Out:
#    Year ZIP Code                           Causes of Death  Count
# 0  1999    90001                       Alzheimer's Disease      3
# 1  1999    90001             Malignant Neoplasms (Cancers)     53
# 2  1999    90001  Chronic Lower Respiratory Disease (CLRD)     16
# 3  1999    90001                         Diabetes Mellitus     16
# 4  1999    90001                                  Homicide     11

# %%
DeathByZip_df_2016 = DeathByZip_df_transformed.loc[DeathByZip_df_transformed['Year']==2016]
DeathByZip_df_2016.head()
# Out:
#         Year ZIP Code                           Causes of Death  Count
# 388107  2016    90001                     Diseases of the Heart     77
# 388108  2016    90001             Malignant Neoplasms (Cancers)     39
# 388109  2016    90001          Cerebrovascular Disease (Stroke)     12
# 388110  2016    90001  Chronic Lower Respiratory Disease (CLRD)      7
# 388111  2016    90001                       Alzheimer's Disease      5

# %%
DeathByZip_df_2016_renamed = DeathByZip_df_2016.rename({'ZIP Code':'ZIPCode'}, axis='columns')
DeathByZip_df_2016_renamed.head()
# Out:
#         Year ZIPCode                           Causes of Death  Count
# 388107  2016   90001                     Diseases of the Heart     77
# 388108  2016   90001             Malignant Neoplasms (Cancers)     39
# 388109  2016   90001          Cerebrovascular Disease (Stroke)     12
# 388110  2016   90001  Chronic Lower Respiratory Disease (CLRD)      7
# 388111  2016   90001                       Alzheimer's Disease      5
